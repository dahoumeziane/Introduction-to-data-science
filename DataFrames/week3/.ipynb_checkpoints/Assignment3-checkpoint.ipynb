# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('EnergyIndicators.xls')
df=df[17:244]
df
# Out:
#      Unnamed: 0                 Unnamed: 1                 Unnamed: 2  \
# 17          NaN                Afghanistan                Afghanistan
# 18          NaN                    Albania                    Albania
# 19          NaN                    Algeria                    Algeria
# 20          NaN             American Samoa             American Samoa
# 21          NaN                    Andorra                    Andorra
# ..          ...                        ...                        ...
# 239         NaN                   Viet Nam                   Viet Nam
# 240         NaN  Wallis and Futuna Islands  Wallis and Futuna Islands
# 241         NaN                      Yemen                      Yemen
# 242         NaN                     Zambia                     Zambia
# 243         NaN                   Zimbabwe                   Zimbabwe
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5
# 17         321         10    78.6693
# 18         102         35        100
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',inplace=True,axis='columns')
df.drop('Unnamed: 1',inplace=True,axis='columns')

# %%
df.head()
# Out:
#         Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 17     Afghanistan        321         10    78.6693
# 18         Albania        102         35        100
# 19         Algeria       1959         51    0.55101
# 20  American Samoa        ...        ...   0.641026
# 21         Andorra          9        121    88.6957

# %%
df.rename(columns={'Unnamed: 2':'Country','Unnamed: 3':'Energy Supply','Unnamed: 4':'Energy Supply per Capita',
                  'Unnamed: 5':'% Renewable'},inplace=True)
df.head()
# Out:
#            Country Energy Supply Energy Supply per Capita % Renewable
# 17     Afghanistan           321                       10     78.6693
# 18         Albania           102                       35         100
# 19         Algeria          1959                       51     0.55101
# 20  American Samoa           ...                      ...    0.641026
# 21         Andorra             9                      121     88.6957

# %%
def convert_gegajoul(row):

    if row=='...':
        return row
    else :
        return float(row)*1000000

# %%
df['Energy Supply']=df['Energy Supply'].apply(lambda x:convert_gegajoul(x))

# %%
df.head()
# Out:
#            Country Energy Supply Energy Supply per Capita % Renewable
# 17     Afghanistan      3.21e+08                       10     78.6693
# 18         Albania      1.02e+08                       35         100
# 19         Algeria     1.959e+09                       51     0.55101
# 20  American Samoa           ...                      ...    0.641026
# 21         Andorra         9e+06                      121     88.6957

# %%
df=df.reset_index()
df.drop('index',inplace=True,axis='columns')
df.head()
# Out:
#           Country Energy Supply Energy Supply per Capita % Renewable
# 0     Afghanistan      3.21e+08                       10     78.6693
# 1         Albania      1.02e+08                       35         100
# 2         Algeria     1.959e+09                       51     0.55101
# 3  American Samoa           ...                      ...    0.641026
# 4         Andorra         9e+06                      121     88.6957

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'United States'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-362-91d4783d7ff2> in <module>
# ----> 1 df.loc['United States']
# ...

# %%
df=df.rename(index={'Republic of Korea':'South Korea','United States of America20':'United States',
                     'United Kingdom of Great Britain and Northern Ireland':'United Kingdom',
                     'China, Hong Kong Special Administrative Region':'Hong Kong'})
str='Algeria'
str.split('(')
# Out:
# ['Algeria']

# %%
df.drop('index',inplace=True,axis='columns')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-273-5a1533665eb4> in <module>
# ----> 1 df.drop('index',inplace=True,axis='columns')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df.head()
# Out:
#                Energy Supply Energy Supply per Capita % Renewable
# Country
# Afghanistan         3.21e+08                       10     78.6693
# Albania             1.02e+08                       35         100
# Algeria            1.959e+09                       51     0.55101
# American Samoa           ...                      ...    0.641026
# Andorra                9e+06                      121     88.6957

# %%
df=df.reset_index()
df.head()
# Out:
#           Country Energy Supply Energy Supply per Capita % Renewable
# 0     Afghanistan      3.21e+08                       10     78.6693
# 1         Albania      1.02e+08                       35         100
# 2         Algeria     1.959e+09                       51     0.55101
# 3  American Samoa           ...                      ...    0.641026
# 4         Andorra         9e+06                      121     88.6957

# %%
def rename_country(row):
    row=row.split(' (')
    return row[0]
df['Country']=df['Country'].apply(lambda x: rename_country(x))
df.head()
# Out:
#           Country Energy Supply Energy Supply per Capita % Renewable
# 0     Afghanistan      3.21e+08                       10     78.6693
# 1         Albania      1.02e+08                       35         100
# 2         Algeria     1.959e+09                       51     0.55101
# 3  American Samoa           ...                      ...    0.641026
# 4         Andorra         9e+06                      121     88.6957

# %%
df.set_index('Country')
GDP=pd.read_csv('world_bank.csv')

GDP.head()
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                   2016-07-22
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                  Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                       NaN             NaN         NaN
# 1                                       NaN             NaN         NaN
# 2                                       NaN             NaN         NaN
# 3                            Indicator Name  Indicator Code      1960.0
# 4  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
GDP=GDP.rename(columns=GDP.iloc[3])
GDP=GDP[4:-1]
GDP=GDP.reset_index()

# %%
GDP.drop('index',inplace=True,axis='columns')

# %%
GDP.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1      Andorra          AND  GDP at market prices (constant 2010 US$)
# 2  Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3       Angola          AGO  GDP at market prices (constant 2010 US$)
# 4      Albania          ALB  GDP at market prices (constant 2010 US$)
#
#    Indicator Code  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...  \
# 0  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 1  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 2  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 3  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 4  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
#          2006.0        2007.0        2008.0        2009.0        2010.0  \
# ...

# %%
columns=GDP.columns
columns
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                  1960.0,           1961.0,           1962.0,           1963.0,
#                  1964.0,           1965.0,           1966.0,           1967.0,
#                  1968.0,           1969.0,           1970.0,           1971.0,
#                  1972.0,           1973.0,           1974.0,           1975.0,
#                  1976.0,           1977.0,           1978.0,           1979.0,
#                  1980.0,           1981.0,           1982.0,           1983.0,
#                  1984.0,           1985.0,           1986.0,           1987.0,
#                  1988.0,           1989.0,           1990.0,           1991.0,
#                  1992.0,           1993.0,           1994.0,           1995.0,
#                  1996.0,           1997.0,           1998.0,           1999.0,
#                  2000.0,           2001.0,           2002.0,           2003.0,
# ...

# %%
my_columns=list()
my_columns=['Country Name',   'Country Code', 'Indicator Name', 'Indicator Code']
for element in columns[4:len(columns)]:
    GDP=GDP.rename(columns={element:int(element)})

# %%
GDP.rename(columns={'Country Name':'Country'},inplace=True)

# %%
GDP=GDP.set_index('Country')

# %%
GDP.rename(index={'Korea, Rep.':'South Korea','Iran, Islamic Rep.':'Iran',
                     'Hong Kong SAR, China':'Hong Kong'
                     },inplace=True)

# %%
'South Korea' in GDP.index
# Out:
# True

# %%
ScimEn=pd.read_excel('scimagojr-3.xlsx')
ScimEn.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# 3           37874                    9.84      139
# 4           12422                    1.85       57

# %%
df.head()
# Out:
#           Country Energy Supply Energy Supply per Capita % Renewable
# 0     Afghanistan      3.21e+08                       10     78.6693
# 1         Albania      1.02e+08                       35         100
# 2         Algeria     1.959e+09                       51     0.55101
# 3  American Samoa           ...                      ...    0.641026
# 4         Andorra         9e+06                      121     88.6957

# %%
GDP.head()
# Out:
#             Country Code                            Indicator Name  \
# Country
# Aruba                ABW  GDP at market prices (constant 2010 US$)
# Andorra              AND  GDP at market prices (constant 2010 US$)
# Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# Angola               AGO  GDP at market prices (constant 2010 US$)
# Albania              ALB  GDP at market prices (constant 2010 US$)
#
#              Indicator Code  1960  1961  1962  1963  1964  1965  1966  ...  \
# Country                                                                ...
# Aruba        NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Andorra      NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Afghanistan  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola       NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Albania      NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
# ...

# %%
ScimEn=ScimEn.set_index('Rank')
ScimEn.head(15)
# Out:
#                  Country  Documents  Citable documents  Citations  \
# Rank
# 1                  China     127050             126767     597237
# 2          United States      96661              94747     792274
# 3                  Japan      30504              30287     223024
# 4         United Kingdom      20944              20357     206091
# 5     Russian Federation      18534              18301      34266
# 6                 Canada      17899              17620     215003
# 7                Germany      17027              16831     140566
# 8                  India      15005              14841     128763
# 9                 France      13153              12973     130632
# 10           South Korea      11983              11923     114675
# 11                 Italy      10964              10794     111850
# 12                 Spain       9428               9330     123336
# 13                  Iran       8896               8819      57470
# ...

# %%
ScimEn[0:15]
# Out:
#                  Country  Documents  Citable documents  Citations  \
# Rank
# 1                  China     127050             126767     597237
# 2          United States      96661              94747     792274
# 3                  Japan      30504              30287     223024
# 4         United Kingdom      20944              20357     206091
# 5     Russian Federation      18534              18301      34266
# 6                 Canada      17899              17620     215003
# 7                Germany      17027              16831     140566
# 8                  India      15005              14841     128763
# 9                 France      13153              12973     130632
# 10           South Korea      11983              11923     114675
# 11                 Italy      10964              10794     111850
# 12                 Spain       9428               9330     123336
# 13                  Iran       8896               8819      57470
# ...

# %%
ScimEn=ScimEn.reset_index()
ScimEn=ScimEn.set_index('Country')
ScimEn.head()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
#
#                     Self-citations  Citations per document  H index
# Country
# China                       411683                    4.70      138
# United States               265436                    8.20      230
# Japan                        61554                    7.31      134
# United Kingdom               37874                    9.84      139
# Russian Federation           12422                    1.85       57

# %%
result=pd.merge(ScimEn[0:15],df,how='inner',left_index=True,right_index=True)

# %%
newgdp=GDP[[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]].copy()

# %%
df.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        ...
#        'United States Virgin Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela', 'Viet Nam', 'Wallis and Futuna Islands', 'Yemen', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name='Country', length=227)

# %%
result=pd.merge(ScimEn,newgdp,how='inner',left_index=True,right_index=True)
result
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# ...                  ...        ...                ...        ...
# Maldives             183          1                  1          1
# Belize               185          1                  1          6
# Palau                186          1                  1          0
# Guyana               187          1                  1          0
# Mauritania           191          1                  1          1
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# ...

# %%
finalresult=pd.merge(result,df,how='left',left_index=True,right_index=True)
finalresult
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# ...                  ...        ...                ...        ...
# Maldives             183          1                  1          1
# Belize               185          1                  1          6
# Palau                186          1                  1          0
# Guyana               187          1                  1          0
# Mauritania           191          1                  1          1
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# ...

# %%
finalresult.shape[0]-15
# Out:
# 150

# %% [markdown]
# ## Question 3

# %%
newgdp['mean']=newgdp.mean(axis=1)
newgdp.head()
# Out:
#                      2006          2007          2008          2009  \
# Country
# Aruba                 NaN           NaN           NaN           NaN
# Andorra      4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# Afghanistan  1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# Angola       5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# Albania      9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
#
#                      2010          2011          2012          2013  \
# Country
# Aruba        2.467704e+09           NaN           NaN           NaN
# Andorra      3.346317e+09  3.185605e+09  3.129538e+09  3.127550e+09
# Afghanistan  1.593680e+10  1.691113e+10  1.935220e+10  1.973134e+10
# Angola       8.247091e+10  8.570262e+10  9.012096e+10  9.626143e+10
# Albania      1.192695e+10  1.223109e+10  1.240477e+10  1.254247e+10
#
#                      2014          2015          mean
# Country
# Aruba                 NaN           NaN  2.467704e+09
# ...

# %%
newgdp['mean']
# Out:
# Country
# Aruba               2.467704e+09
# Andorra             3.504957e+09
# Afghanistan         1.610842e+10
# Angola              8.412116e+10
# Albania             1.177673e+10
#                         ...
# Samoa               6.788420e+08
# Yemen, Rep.         2.812942e+10
# South Africa        3.823935e+11
# Congo, Dem. Rep.    2.208075e+10
# Zambia              2.057734e+10
# Name: mean, Length: 263, dtype: float64

# %%
ts = pd.Series(newgdp['mean'].values,index=newgdp.index)

# %%
ts
# Out:
# Country
# Aruba               2.467704e+09
# Andorra             3.504957e+09
# Afghanistan         1.610842e+10
# Angola              8.412116e+10
# Albania             1.177673e+10
#                         ...
# Samoa               6.788420e+08
# Yemen, Rep.         2.812942e+10
# South Africa        3.823935e+11
# Congo, Dem. Rep.    2.208075e+10
# Zambia              2.057734e+10
# Length: 263, dtype: float64

# %%
ts.sort_values(ascending=False)
# Out:
# Country
# World                        6.713548e+13
# High income                  4.586468e+13
# OECD members                 4.514723e+13
# Post-demographic dividend    4.292131e+13
# IDA & IBRD total             2.202600e+13
#                                  ...
# Sint Maarten (Dutch part)             NaN
# Syrian Arab Republic                  NaN
# Turks and Caicos Islands              NaN
# British Virgin Islands                NaN
# Virgin Islands (U.S.)                 NaN
# Length: 263, dtype: float64

# %%
finalresult.head()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# United States               265436                    8.20      230
# Japan                        61554                    7.31      134
# United Kingdom               37874                    9.84      139
# Russian Federation           12422                    1.85       57
#
#                             2006          2007          2008  ...  \
# Country                                                       ...
# ...

# %%
finalresult['mean']=finalresult.loc[:, [2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]].mean(axis=1)

# %%
finalresult.head(6)
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# United States               265436                    8.20      230
# Japan                        61554                    7.31      134
# United Kingdom               37874                    9.84      139
# Russian Federation           12422                    1.85       57
# Canada                       40930                   12.01      149
#
# ...

# %%
ts = pd.Series(finalresult['mean'].values,index=finalresult.index)
ts
# Out:
# Country
# China                 6.348609e+12
# United States         1.536434e+13
# Japan                 5.542208e+12
# United Kingdom        2.487907e+12
# Russian Federation    1.565459e+12
#                           ...
# Maldives              2.440296e+09
# Belize                1.423214e+09
# Palau                 1.983187e+08
# Guyana                2.353793e+09
# Mauritania            4.509228e+09
# Length: 165, dtype: float64

# %%
ts=ts.sort_values(ascending=False)

# %%
ts.iloc[0:15]

# %% [markdown]
# ## Question 4

# %%
'China' in ts.index
# Out:
# True

# %%
unique_index=ts.index
unique_index
# Out:
# Index(['United States', 'China', 'Japan', 'Germany', 'France',
#        'United Kingdom', 'Brazil', 'Italy', 'India', 'Canada',
#        'Russian Federation', 'Spain', 'Australia', 'South Korea', 'Mexico'],
#       dtype='object', name='Country')

# %%
unique_index[5]
# Out:
# 'United Kingdom'

# %%
finalresult.loc[unique_index[5]][2015]-finalresult.loc[unique_index[5]][2006]
# Out:
# 246702696075.3999

# %% [markdown]
# ## Question 5

# %%
df.head()
# Out:
#           Country Energy Supply Energy Supply per Capita % Renewable
# 0     Afghanistan      3.21e+08                       10     78.6693
# 1         Albania      1.02e+08                       35         100
# 2         Algeria     1.959e+09                       51     0.55101
# 3  American Samoa           ...                      ...    0.641026
# 4         Andorra         9e+06                      121     88.6957

# %%
df['Energy Supply per Capita']
tts=df['Energy Supply per Capita']

# %%
tts=pd.to_numeric(tts, errors='coerce')

# %%
np.nanmean(tts)
# Out:
# 90.66666666666667

# %% [markdown]
# ## Question 6

# %%
df.head()
# Out:
#           Country Energy Supply Energy Supply per Capita % Renewable
# 0     Afghanistan      3.21e+08                       10     78.6693
# 1         Albania      1.02e+08                       35         100
# 2         Algeria     1.959e+09                       51     0.55101
# 3  American Samoa           ...                      ...    0.641026
# 4         Andorra         9e+06                      121     88.6957

# %%
renew_ts
# Out:
# Country
# China                 NaN
# United States         NaN
# Japan                 NaN
# United Kingdom        NaN
# Russian Federation    NaN
#                      ...
# Maldives              NaN
# Belize                NaN
# Palau                 NaN
# Guyana                NaN
# Mauritania            NaN
# Length: 165, dtype: object

# %%
finalresult['% Renewable']
# Out:
# Country
# China                 NaN
# United States         NaN
# Japan                 NaN
# United Kingdom        NaN
# Russian Federation    NaN
#                      ...
# Maldives              NaN
# Belize                NaN
# Palau                 NaN
# Guyana                NaN
# Mauritania            NaN
# Name: % Renewable, Length: 165, dtype: object

# %%
newgdp=GDP[[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]].copy()
result=pd.merge(ScimEn,newgdp,how='inner',left_index=True,right_index=True)
finalresult=pd.merge(result,df,how='left',left_index=True,right_index=True)

# %%
df=df.set_index('Country')

# %%
finalresult
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# ...                  ...        ...                ...        ...
# Maldives             183          1                  1          1
# Belize               185          1                  1          6
# Palau                186          1                  1          0
# Guyana               187          1                  1          0
# Mauritania           191          1                  1          1
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# ...

# %%
renew_ts = pd.Series(finalresult['% Renewable'].values,index=finalresult.index)
renew_ts=renew_ts.sort_values(ascending=False)
renew_ts
# Out:
# Country
# Bhutan               100
# Albania              100
# Lesotho              100
# Paraguay          99.995
# Iceland          99.9724
#                   ...
# Moldova              NaN
# Tanzania             NaN
# Monaco               NaN
# Faroe Islands        NaN
# Greenland            NaN
# Length: 165, dtype: object

# %%
tup=(renew_ts.index[0],renew_ts[0])
tup
# Out:
# ('Bhutan', 100)

# %%
renew_ts = pd.Series(finalresult['% Renewable'].values,index=finalresult.index)
renew_ts=renew_ts.sort_values(ascending=False)
renew_ts.index[0],renew_ts[0]
finalresult
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# ...                  ...        ...                ...        ...
# Maldives             183          1                  1          1
# Belize               185          1                  1          6
# Palau                186          1                  1          0
# Guyana               187          1                  1          0
# Mauritania           191          1                  1          1
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# ...

# %% [markdown]
# ## Question 7

# %%
ScimEn.head()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
#
#                     Self-citations  Citations per document  H index
# Country
# China                       411683                    4.70      138
# United States               265436                    8.20      230
# Japan                        61554                    7.31      134
# United Kingdom               37874                    9.84      139
# Russian Federation           12422                    1.85       57

# %%
ScimEn['ratio']=ScimEn['Self-citations']/ScimEn['Citations']

# %%
ScimEn.head()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
#
#                     Self-citations  Citations per document  H index     ratio
# Country
# China                       411683                    4.70      138  0.689313
# United States               265436                    8.20      230  0.335031
# Japan                        61554                    7.31      134  0.275997
# United Kingdom               37874                    9.84      139  0.183773
# Russian Federation           12422                    1.85       57  0.362517

# %%
ratio_ts=pd.Series(ScimEn['ratio'].values,index=ScimEn.index)
ratio_ts=ratio_ts.sort_values(ascending=False)
ratio_ts
# Out:
# Country
# French Guiana       1.000000
# China               0.689313
# Monaco              0.555556
# Faroe Islands       0.500000
# Reunion             0.500000
#                       ...
# Gambia                   NaN
# Palau                    NaN
# Guyana                   NaN
# Christmas Island         NaN
# Saint Lucia              NaN
# Length: 191, dtype: float64

# %%
ScimEn.loc['French Guiana']
# Out:
# Rank                      165.00
# Documents                   3.00
# Citable documents           3.00
# Citations                   1.00
# Self-citations              1.00
# Citations per document      0.33
# H index                     1.00
# ratio                       1.00
# Name: French Guiana, dtype: float64

# %% [markdown]
# ## Question 8

# %%
df.head()
# Out:
#                Energy Supply Energy Supply per Capita % Renewable
# Country
# Afghanistan         3.21e+08                       10     78.6693
# Albania             1.02e+08                       35         100
# Algeria            1.959e+09                       51     0.55101
# American Samoa           ...                      ...    0.641026
# Andorra                9e+06                      121     88.6957

# %%
df['Energy Supply']=pd.to_numeric(df['Energy Supply'], errors='coerce')

# %%
df['Energy Supply per Capita']=pd.to_numeric(df['Energy Supply per Capita'], errors='coerce')

# %%
df['Population']=df['Energy Supply']/df['Energy Supply per Capita']

# %%
df.head()
# Out:
#                 Energy Supply  Energy Supply per Capita % Renewable  \
# Country
# Afghanistan      3.210000e+08                      10.0     78.6693
# Albania          1.020000e+08                      35.0         100
# Algeria          1.959000e+09                      51.0     0.55101
# American Samoa            NaN                       NaN    0.641026
# Andorra          9.000000e+06                     121.0     88.6957
#
#                   Population
# Country
# Afghanistan     3.210000e+07
# Albania         2.914286e+06
# Algeria         3.841176e+07
# American Samoa           NaN
# Andorra         7.438017e+04

# %%
pop_ts=pd.Series(df['Population'].values,index=df.index)
pop_ts=pop_ts.sort_values(ascending=False)

print('Third population are from',(pop_ts.index[2],pop_ts[2]))
pop_ts
# Out:
# Third population are from ('United States of America20', 317615384.61538464)
# Country
# China2                          1.367645e+09
# India                           1.276731e+09
# United States of America20      3.176154e+08
# Indonesia8                      2.501143e+08
# Brazil                          2.059153e+08
#                                     ...
# American Samoa                           NaN
# Guam                                     NaN
# Northern Mariana Islands                 NaN
# Tuvalu                                   NaN
# United States Virgin Islands             NaN
# Length: 227, dtype: float64

# %% [markdown]
# ## Question 9

# %%
ScimEn.head()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
#
#                     Self-citations  Citations per document  H index     ratio
# Country
# China                       411683                    4.70      138  0.689313
# United States               265436                    8.20      230  0.335031
# Japan                        61554                    7.31      134  0.275997
# United Kingdom               37874                    9.84      139  0.183773
# Russian Federation           12422                    1.85       57  0.362517

# %%
mergedf=pd.merge(df,ScimEn,how='inner',left_index=True,right_index=True)
mergedf
# Out:
#                 Energy Supply  Energy Supply per Capita % Renewable  \
# Country
# Afghanistan      3.210000e+08                      10.0     78.6693
# Albania          1.020000e+08                      35.0         100
# Algeria          1.959000e+09                      51.0     0.55101
# American Samoa            NaN                       NaN    0.641026
# Andorra          9.000000e+06                     121.0     88.6957
# ...                       ...                       ...         ...
# Venezuela        2.871000e+09                      95.0     67.8345
# Viet Nam         2.554000e+09                      28.0     45.3215
# Yemen            3.440000e+08                      13.0           0
# Zambia           4.000000e+08                      26.0     99.7147
# Zimbabwe         4.800000e+08                      32.0     52.5361
#
#                   Population  Rank  Documents  Citable documents  Citations  \
# Country
# ...

# %%
mergedf['Citable documents per capita']=mergedf['Citable documents']/mergedf['Population']

# %%
mergedf.head()
# Out:
#                 Energy Supply  Energy Supply per Capita % Renewable  \
# Country
# Afghanistan      3.210000e+08                      10.0     78.6693
# Albania          1.020000e+08                      35.0         100
# Algeria          1.959000e+09                      51.0     0.55101
# American Samoa            NaN                       NaN    0.641026
# Andorra          9.000000e+06                     121.0     88.6957
#
#                   Population  Rank  Documents  Citable documents  Citations  \
# Country
# Afghanistan     3.210000e+07   163          3                  3          0
# Albania         2.914286e+06   118         23                 23        168
# Algeria         3.841176e+07    42       1215               1197       7393
# American Samoa           NaN   180          1                  1          0
# Andorra         7.438017e+04   168          2                  2         13
#
#                 Self-citations  Citations per document  H index     ratio  \
# ...

# %%
mergedf['Citable documents per capita']=pd.to_numeric(mergedf['Citable documents per capita'])
mergedf['Energy Supply per Capita']=pd.to_numeric(mergedf['Energy Supply per Capita'])
mergedf['Energy Supply per Capita'].corr(mergedf['Citable documents per capita'],method ='pearson')
# Out:
# nan

# %%
mergedf['Citable documents per capita'].corr(mergedf['Energy Supply per Capita'])
# Out:
# nan

# %%
corrdf=mergedf[['Citable documents per capita','Energy Supply per Capita']].copy()

# %%
corrdf.corr(method='pearson')
# Out:
#                               Citable documents per capita  \
# Citable documents per capita                      1.000000
# Energy Supply per Capita                          0.548489
#
#                               Energy Supply per Capita
# Citable documents per capita                  0.548489
# Energy Supply per Capita                      1.000000

# %%
corrdf.corr(method='pearson')['Citable documents per capita']['Energy Supply per Capita']
# Out:
# 0.5484893309480758

# %% [markdown]
# ## Question 10

# %%
finalresult
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# ...                  ...        ...                ...        ...
# Maldives             183          1                  1          1
# Belize               185          1                  1          6
# Palau                186          1                  1          0
# Guyana               187          1                  1          0
# Mauritania           191          1                  1          1
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# ...

# %%
finalresult[0:15]['% Renewable'].median()
# Out:
# 17.28868

# %%
def HighRenew(row):
    if row>=finalresult[0:15]['% Renewable'].median():
        return 1
    else:
        return 0
finalresult['HighRenew']=finalresult['% Renewable'].apply(lambda x :HighRenew(x))
finalresult.head()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# United States               265436                    8.20      230
# Japan                        61554                    7.31      134
# United Kingdom               37874                    9.84      139
# Russian Federation           12422                    1.85       57
#
#                             2006          2007          2008  ...  \
# Country                                                       ...
# ...

# %%
HighRenew=pd.Series(finalresult['HighRenew'].values,index=finalresult.index)


HighRenew
# Out:
# Country
# China                 0
# United States         0
# Japan                 0
# United Kingdom        0
# Russian Federation    1
#                      ..
# Maldives              0
# Belize                1
# Palau                 1
# Guyana                0
# Mauritania            0
# Length: 165, dtype: int64

# %%
def answer_one():
    import pandas as pd
    global finalresult,Energy,ScimEn
    Energy=pd.read_excel('assets/Energy Indicators.xls')
    Energy=Energy[17:244]
    Energy.drop('Unnamed: 0',inplace=True,axis='columns')
    Energy.drop('Unnamed: 1',inplace=True,axis='columns')
    Energy.rename(columns={'Unnamed: 2':'Country','Unnamed: 3':'Energy Supply','Unnamed: 4':'Energy Supply per Capita',
                  'Unnamed: 5':'% Renewable'},inplace=True)
    Energy['Energy Supply']=Energy['Energy Supply'].apply(lambda x:convert_gegajoul(x))
    Energy=Energy.reset_index()
    Energy.drop('index',inplace=True,axis='columns')
    Energy=Energy.set_index('Country')
    Energy=Energy.rename(index={'Republic of Korea':'South Korea','United States of America':'United States',
                     'United Kingdom of Great Britain and Northern Ireland':'United Kingdom',
                     'China, Hong Kong Special Administrative Region':'Hong Kong'})
    Energy=Energy.reset_index()
    Energy['Country']=Energy['Country'].apply(lambda x: rename_country(x))
    Energy=Energy.set_index('Country')
    
    #Reading the second file
    GDP=pd.read_csv('assets/world_bank.csv')
    GDP=GDP.rename(columns=GDP.iloc[3])
    GDP=GDP[4:-1]
    GDP=GDP.reset_index()
    GDP.drop('index',inplace=True,axis='columns')
    for element in GDP.columns[4:len(GDP.columns)]:
        GDP=GDP.rename(columns={element:int(element)})
    GDP.rename(columns={'Country Name':'Country'},inplace=True)
    GDP=GDP.set_index('Country')
    GDP.rename(index={'Korea, Rep.':'South Korea','Iran, Islamic Rep.':'Iran',
                     'Hong Kong SAR, China':'Hong Kong'
                     },inplace=True)
    #Read the third file
    ScimEn=pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn=ScimEn.set_index('Country')
    newgdp=GDP[[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]].copy()
    result=pd.merge(ScimEn,newgdp,how='inner',left_index=True,right_index=True)
    finalresult=pd.merge(result,Energy,how='left',left_index=True,right_index=True)
    return finalresult[0:15]
