# %%
import pandas as pd
import numpy as np
import re
nhl_df=pd.read_csv("datasets/nhl.csv")
cities=pd.read_html("datasets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

# %%
nhl_cities=cities[['Metropolitan area','NHL','Population (2016 est.)[8]']]

# %%
nhl_cities=nhl_cities.set_index('NHL')
nhl_cities=nhl_cities.rename(index={'RangersIslandersDevils[note 3]':'Rangers',
                        'KingsDucks':'Kings'})
nhl_cities.loc['Islanders']=None
nhl_cities.loc['Devils']=None
nhl_cities.loc['Ducks']=None
nhl_cities['Population']=nhl_cities['Population (2016 est.)[8]']

nhl_cities.loc['Islanders']['Metropolitan area']='New York City'
nhl_cities.loc['Islanders']['Population (2016 est.)[8]']=20153634
nhl_cities.loc['Devils']['Metropolitan area']='New Jersey'
nhl_cities.loc['Devils']['Population (2016 est.)[8]']=20153634
nhl_cities.loc['Ducks']['Metropolitan area']='Anaheim'
nhl_cities.loc['Ducks']['Population (2016 est.)[8]']=13310447
nhl_cities=nhl_cities.reset_index()
nhl_cities['NHL']=nhl_cities['NHL'].str.replace('\[.*\]',"")

# %%
nhl_cities=nhl_cities.set_index('Metropolitan area')

nhl_cities.rename(index={'Miami–Fort Lauderdale':'Florida',
    'New York City':'New York',
                         'Minneapolis–Saint Paul':'Minnesota','Washington, D.C.':'Washington'
                         ,'Dallas–Fort Worth':'Dallas',
                         'Tampa Bay Area':'Tampa Bay'},inplace=True)

# %%
nhl_cities=nhl_cities.reset_index()
nhl_cities=nhl_cities.set_index('NHL')
nhl_cities.loc['Golden Knights']['Metropolitan area']='Vegas'
nhl_cities.loc['Hurricanes']['Metropolitan area']='Carolina'

nhl_cities.loc['Coyotes']['Metropolitan area']='Arizona'



nhl_cities.reset_index(inplace=True)
nhl_cities['team']=nhl_cities['Metropolitan area']+' '+nhl_cities['NHL']

# %%
nhl_df=nhl_df[nhl_df['year']==2018]
nhl_df['team']=nhl_df['team'].str.replace('*','')
nhl_df=nhl_df.set_index('team')
nhl_cities=nhl_cities.set_index('team')
mergeddf=pd.merge(nhl_df,nhl_cities,how='inner',left_index=True,right_index=True)

# %%
mergeddf['W']=pd.to_numeric(mergeddf['W'])
mergeddf['L']=pd.to_numeric(mergeddf['L'])
def calculate_ratio(row):
    
    return row.loc['W']/(row.loc['W']+row.loc['L'])

mergeddf['ratio']=mergeddf.apply(calculate_ratio,axis='columns')

# %%
mergeddf=mergeddf[['W','L','NHL','ratio','Population (2016 est.)[8]']]

# %%
mergeddf
# Out:
#                         W   L             NHL     ratio  \
# team
# Tampa Bay Lightning    54  23       Lightning  0.647947
# Boston Bruins          50  20          Bruins  0.714286
# Toronto Maple Leafs    49  26     Maple Leafs  0.653333
# Florida Panthers       44  30        Panthers  0.647947
# Detroit Red Wings      30  39       Red Wings  0.434783
# Montreal Canadiens     29  40       Canadiens  0.420290
# Ottawa Senators        28  43        Senators  0.394366
# Buffalo Sabres         25  45          Sabres  0.357143
# Washington Capitals    49  26        Capitals  0.653333
# Pittsburgh Penguins    47  29        Penguins  0.618421
# Philadelphia Flyers    42  26          Flyers  0.617647
# Columbus Blue Jackets  45  30    Blue Jackets  0.600000
# New Jersey Devils      44  29          Devils  0.518201
# Carolina Hurricanes    36  35      Hurricanes  0.507042
# New York Islanders     35  37       Islanders  0.518201
# New York Rangers       34  39         Rangers  0.518201
# Nashville Predators    53  18       Predators  0.746479
# Winnipeg Jets          52  20            Jets  0.722222
# Minnesota Wild         45  26            Wild  0.633803
# St. Louis Blues        44  32           Blues  0.578947
# Dallas Stars           42  32           Stars  0.567568
# Chicago Blackhawks     33  39      Blackhawks  0.458333
# Vegas Golden Knights   51  24  Golden Knights  0.680000
# Anaheim Ducks          44  25           Ducks  0.637681
# Los Angeles Kings      45  29           Kings  0.608108
# Calgary Flames         37  35          Flames  0.513889
# Edmonton Oilers        36  40          Oilers  0.473684
# Vancouver Canucks      31  40         Canucks  0.436620
# Arizona Coyotes        29  41         Coyotes  0.414286
#
#                       Population (2016 est.)[8]
# team
# Tampa Bay Lightning                     3032171
# Boston Bruins                           4794447
# Toronto Maple Leafs                     5928040
# Florida Panthers                        6066387
# Detroit Red Wings                       4297617
# Montreal Canadiens                      4098927
# Ottawa Senators                         1323783
# Buffalo Sabres                          1132804
# Washington Capitals                     6131977
# Pittsburgh Penguins                     2342299
# Philadelphia Flyers                     6070500
# Columbus Blue Jackets                   2041520
# New Jersey Devils                      20153634
# Carolina Hurricanes                     1302946
# New York Islanders                     20153634
# New York Rangers                       20153634
# Nashville Predators                     1865298
# Winnipeg Jets                            778489
# Minnesota Wild                          3551036
# St. Louis Blues                         2807002
# Dallas Stars                            7233323
# Chicago Blackhawks                      9512999
# Vegas Golden Knights                    2155664
# Anaheim Ducks                          13310447
# Los Angeles Kings                      13310447
# Calgary Flames                          1392609
# Edmonton Oilers                         1321426
# Vancouver Canucks                       2463431
# Arizona Coyotes                         4661537

# %%
mergeddf=mergeddf.reset_index()
mergeddf=mergeddf.set_index('team')
nb=(mergeddf.loc['New York Islanders']['ratio']+mergeddf.loc['New York Rangers']['ratio']+mergeddf.loc['New Jersey Devils']['ratio'])/3
mergeddf.at['New York Islanders','ratio']=nb
mergeddf.at['New York Rangers','ratio']=nb
mergeddf.at['New Jersey Devils','ratio']=nb

# %%
b=(mergeddf.loc['Tampa Bay Lightning']['ratio']+mergeddf.loc['Florida Panthers']['ratio'])/2
#mergeddf.at['Tampa Bay Lightning','ratio']=b
#mergeddf.at['Florida Panthers','ratio']=b

#
#mergeddf.at['Anaheim Ducks','ratio']=0.6228945

#mergeddf.at['Florida Panthers','ratio']=0.6228945
b
# Out:
# 0.647946647946648

# %%
mergeddf.at['Tampa Bay Lightning','ratio']=b

# %%
mergeddf.at['Florida Panthers','ratio']=b

# %%
n=(mergeddf.loc['Los Angeles Kings']['ratio']+mergeddf.loc['Anaheim Ducks']['ratio'])/2
n
# Out:
# 0.622894633764199

# %%
mergeddf.at['Anaheim Ducks','ratio']=n

mergeddf.at['Florida Panthers','ratio']=n

# %%
mergeddf.reset_index(inplace=True)

# %%
mergeddf=mergeddf.set_index('Metropolitan area')

# %%
mergeddf=mergeddf.rename(index={'New Jersey':'New York','Anaheim':'Los Angeles','Tampa Bay':'Florida'})

# %%
mergeddf=mergeddf[['W','L','team','NHL','ratio','Population (2016 est.)[8]']]

# %%
mergeddf.shape
# Out:
# (28, 6)

# %%
import scipy.stats as stats
mergeddf['Population (2016 est.)[8]']=pd.to_numeric(mergeddf['Population (2016 est.)[8]'])
population_by_region = mergeddf['Population (2016 est.)[8]']
win_loss_by_region = mergeddf['ratio']
stats.pearsonr(population_by_region, win_loss_by_region)
# Out:
# (-0.03993752870435047, 0.8370318125996856)

# %%
nhl_cities
# Out:
#                                           NHL       Metropolitan area  \
# team
# New York Rangers                      Rangers                New York
# Los Angeles Kings                       Kings             Los Angeles
# San Francisco Bay Area Sharks          Sharks  San Francisco Bay Area
# Chicago Blackhawks                 Blackhawks                 Chicago
# Dallas Stars                            Stars                  Dallas
# Washington Capitals                  Capitals              Washington
# Philadelphia Flyers                    Flyers            Philadelphia
# Boston Bruins                          Bruins                  Boston
# Minnesota Wild                           Wild               Minnesota
# Denver Avalanche                    Avalanche                  Denver
# Florida Panthers                     Panthers                 Florida
# Arizona Coyotes                       Coyotes                 Arizona
# Detroit Red Wings                   Red Wings                 Detroit
# Toronto Maple Leafs               Maple Leafs                 Toronto
# Houston —                                   —                 Houston
# Atlanta                                                       Atlanta
# Tampa Bay Lightning                 Lightning               Tampa Bay
# Pittsburgh Penguins                  Penguins              Pittsburgh
# Cleveland                                                   Cleveland
# Seattle                                                       Seattle
# Cincinnati —                                —              Cincinnati
# Kansas City                                               Kansas City
# St. Louis Blues                         Blues               St. Louis
# Baltimore —                                 —               Baltimore
# Charlotte —                                 —               Charlotte
# Indianapolis —                              —            Indianapolis
# Nashville Predators                 Predators               Nashville
# Milwaukee —                                 —               Milwaukee
# New Orleans —                               —             New Orleans
# Buffalo Sabres                         Sabres                 Buffalo
# Montreal Canadiens                  Canadiens                Montreal
# Vancouver Canucks                     Canucks               Vancouver
# Orlando —                                   —                 Orlando
# Portland —                                  —                Portland
# Columbus Blue Jackets            Blue Jackets                Columbus
# Calgary Flames                         Flames                 Calgary
# Ottawa Senators                      Senators                  Ottawa
# Edmonton Oilers                        Oilers                Edmonton
# Salt Lake City —                            —          Salt Lake City
# Winnipeg Jets                            Jets                Winnipeg
# San Diego —                                 —               San Diego
# San Antonio —                               —             San Antonio
# Sacramento —                                —              Sacramento
# Vegas Golden Knights           Golden Knights                   Vegas
# Jacksonville —                              —            Jacksonville
# Oklahoma City —                             —           Oklahoma City
# Memphis —                                   —                 Memphis
# Carolina Hurricanes                Hurricanes                Carolina
# Green Bay —                                 —               Green Bay
# Hamilton                                                     Hamilton
# Regina —                                    —                  Regina
# New York Islanders                  Islanders                New York
# New Jersey Devils                      Devils              New Jersey
# Los Angeles Ducks                       Ducks             Los Angeles
#
#                               Population (2016 est.)[8] Population
# team
# New York Rangers                               20153634   20153634
# Los Angeles Kings                              13310447   13310447
# San Francisco Bay Area Sharks                   6657982    6657982
# Chicago Blackhawks                              9512999    9512999
# Dallas Stars                                    7233323    7233323
# Washington Capitals                             6131977    6131977
# Philadelphia Flyers                             6070500    6070500
# Boston Bruins                                   4794447    4794447
# Minnesota Wild                                  3551036    3551036
# Denver Avalanche                                2853077    2853077
# Florida Panthers                                6066387    6066387
# Arizona Coyotes                                 4661537    4661537
# Detroit Red Wings                               4297617    4297617
# Toronto Maple Leafs                             5928040    5928040
# Houston —                                       6772470    6772470
# Atlanta                                         5789700    5789700
# Tampa Bay Lightning                             3032171    3032171
# Pittsburgh Penguins                             2342299    2342299
# Cleveland                                       2055612    2055612
# Seattle                                         3798902    3798902
# Cincinnati —                                    2165139    2165139
# Kansas City                                     2104509    2104509
# St. Louis Blues                                 2807002    2807002
# Baltimore —                                     2798886    2798886
# Charlotte —                                     2474314    2474314
# Indianapolis —                                  2004230    2004230
# Nashville Predators                             1865298    1865298
# Milwaukee —                                     1572482    1572482
# New Orleans —                                   1268883    1268883
# Buffalo Sabres                                  1132804    1132804
# Montreal Canadiens                              4098927    4098927
# Vancouver Canucks                               2463431    2463431
# Orlando —                                       2441257    2441257
# Portland —                                      2424955    2424955
# Columbus Blue Jackets                           2041520    2041520
# Calgary Flames                                  1392609    1392609
# Ottawa Senators                                 1323783    1323783
# Edmonton Oilers                                 1321426    1321426
# Salt Lake City —                                1186187    1186187
# Winnipeg Jets                                    778489     778489
# San Diego —                                     3317749    3317749
# San Antonio —                                   2429609    2429609
# Sacramento —                                    2296418    2296418
# Vegas Golden Knights                            2155664    2155664
# Jacksonville —                                  1478212    1478212
# Oklahoma City —                                 1373211    1373211
# Memphis —                                       1342842    1342842
# Carolina Hurricanes                             1302946    1302946
# Green Bay —                                      318236     318236
# Hamilton                                         747545     747545
# Regina —                                         236481     236481
# New York Islanders                             20153634        NaN
# New Jersey Devils                              20153634        NaN
# Los Angeles Ducks                              13310447        NaN

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

nhl_df=pd.read_csv("assets/nhl.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def nhl_correlation(): 
    # YOUR CODE HERE
    global nhl_df,cities
    nhl_cities=cities[['Metropolitan area','NHL','Population (2016 est.)[8]']]
    nhl_cities=nhl_cities.set_index('NHL')
    nhl_cities=nhl_cities.rename(index={'RangersIslandersDevils[note 3]':'Rangers',
                        'KingsDucks':'Kings'})
    nhl_cities.loc['Islanders']=None
    nhl_cities.loc['Devils']=None
    nhl_cities.loc['Ducks']=None
    nhl_cities['Population']=nhl_cities['Population (2016 est.)[8]']

    nhl_cities.loc['Islanders']['Metropolitan area']='New York City'
    nhl_cities.loc['Islanders']['Population (2016 est.)[8]']=20153634
    nhl_cities.loc['Devils']['Metropolitan area']='New Jersey'
    nhl_cities.loc['Devils']['Population (2016 est.)[8]']=20153634
    nhl_cities.loc['Ducks']['Metropolitan area']='Anaheim'
    nhl_cities.loc['Ducks']['Population (2016 est.)[8]']=13310447
    nhl_cities=nhl_cities.reset_index()
    nhl_cities['NHL']=nhl_cities['NHL'].str.replace('\[.*\]',"")
    nhl_cities=nhl_cities.set_index('Metropolitan area')
    nhl_cities.rename(index={'New York City':'New York','Miami–Fort Lauderdale':'Florida',
                         'Minneapolis–Saint Paul':'Minnesota','Washington, D.C.':'Washington'
                         ,'Dallas–Fort Worth':'Dallas',
                         'Tampa Bay Area':'Tampa Bay'},inplace=True)
    nhl_cities=nhl_cities.reset_index()
    nhl_cities=nhl_cities.set_index('NHL')
    nhl_cities.loc['Golden Knights']['Metropolitan area']='Vegas'
    nhl_cities.loc['Hurricanes']['Metropolitan area']='Carolina'
    nhl_cities.reset_index(inplace=True)
    nhl_cities['team']=nhl_cities['Metropolitan area']+' '+nhl_cities['NHL']
    nhl_df=nhl_df[nhl_df['year']==2018]
    nhl_df['team']=nhl_df['team'].str.replace('*','')
    nhl_df=nhl_df.set_index('team')
    nhl_cities=nhl_cities.set_index('team')
    mergeddf=pd.merge(nhl_df,nhl_cities,how='inner',left_index=True,right_index=True)
    mergeddf['W']=pd.to_numeric(mergeddf['W'])
    mergeddf['L']=pd.to_numeric(mergeddf['L'])
    def calculate_ratio(row):
        return row.loc['W']/(row.loc['W']+row.loc['L'])
    
    

    mergeddf['ratio']=mergeddf.apply(calculate_ratio,axis='columns')

    mergeddf=mergeddf.reset_index()
    mergeddf=mergeddf.set_index('team')
    nb=(mergeddf.loc['New York Islanders']['ratio']+mergeddf.loc['New York Rangers']['ratio']+mergeddf.loc['New Jersey Devils']['ratio'])/3
    mergeddf.at['New York Islanders','ratio']=nb
    mergeddf.at['New York Rangers','ratio']=nb
    mergeddf.at['New Jersey Devils','ratio']=nb
    
    nb=(mergeddf.loc['Los Angeles Kings']['ratio']+mergeddf.loc['Anaheim Ducks']['ratio'])/2
    mergeddf.at['Los Angeles Kings','ratio']=nb
    mergeddf.at['Anaheim Ducks','ratio']=nb
    
    mergeddf.reset_index(inplace=True)
    mergeddf=mergeddf.set_index('Metropolitan area')
    mergeddf=mergeddf.rename(index={'New Jersey':'New York','Anaheim':'Los Angeles'})
    mergeddf['Population (2016 est.)[8]']=pd.to_numeric(mergeddf['Population (2016 est.)[8]'])
    population_by_region = mergeddf['Population (2016 est.)[8]']
    win_loss_by_region = mergeddf['ratio']
    assert len(population_by_region) == len(win_loss_by_region), "Q1: Your lists must be the same length"
    assert len(population_by_region) == 28, "Q1: There should be 28 teams being analysed for NHL"
    
    return stats.pearsonr(population_by_region, win_loss_by_region)[0]
nhl_correlation()
